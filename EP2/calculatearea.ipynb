# %%
import math
class Shape:
    def __init__(self, sides):
        self.sides = sides
    def calculate_area(self):
        pass
class paralelogram(Shape):
    def __init__(self, sides, leght):
        super().__init__(len(sides))
        self.leght=leght
    def calculate_area(self):
        return f"The area of a parallelogram is {self.sides*self.leght}"
class Circle(Shape):
    def __init__(self, radius):
        super().__init__(radius)
        self.radius = radius
    def calculate_area(self):
        return math.pi * self.radius * self.radius

class Square(Shape):
    def __init__(self, side):
        super().__init__(side)
        self.side = side
    def calculate_area(self):
        return self.side * self.side
class rectangle(Shape):
    def __init__(self, side, bredth):
        super().__init__(side)
        self.side = side
        self.bredth=bredth
    def calculate_area(self):
        return self.side * self.bredth
class Rohmbus(Shape):
    def __init__(self,dia1, dia2):
        # super().__init__(sides)
        self.dia1 = dia1
        self.dia2 = dia2
    def calculate_area(self):
        return (self.dia1 * self.dia2)/2

# Add other shape classes here...
    
# circle == radius
# rectangle == le*b
# square = side*sides
# Rohmbus = (di1*di2)2
# paralelogram = side*height
    choice1=input("Enter the Number of sides")
    while True:
        if choice1 == '4':
            sides=int(input('Enter the leght of sides'))
            base=int(input('Enter the base of the parralelogra'))
            breadth=int(input('Enter the breadth of the rectangle'))
            print(paralelogram(sides,base).calculate_area())
            print(Square(sides).calculate_area())
            print(rectangle(sides, breadth).calculate_area())
        elif choice1 == '0':
            diameter=int(input('Enter the diameter'))
            dia1=int(input('Enter the diagonal 1'))
            dia2=int(input('Enter the diagonal 2'))
            print(Circle(diameter).calculate_area())
            
            print(Rohmbus(dia1, dia2).calculate_area())
        elif choice1 == '9':
            break
        else:
            print("Invalid input! Please enter again.")

    # while True:
    #     print("1. Enter")
    #     print("2. Square")
    #     # Add other shape options here...
    #     print("9. Quit")
    #     choice = input("Enter your choice: ")
    #     if choice == '1':
    #         radius = float(input("Enter the radius: "))
    #         shape = Circle(radius)
    #     elif choice == '2':
    #         side = float(input("Enter the side: "))
    #         shape = Square(side)
    #     elif choice =='3':
    #         num_sides = int(input("How many sides does this shape have? "))
    #         side_length = float(input("What is the length of each side? "))
    #         shape = paralelogram([num_sides],side_length)
    #     elif choice == '4':
    #         d1 = float(input("Enter diameter 1: "))
    #         d2 = float(input("Enter diameter 2: "))
    #         # shape = Rohmbus(d1,d2)
    #     # Add other shape options here...

    #     elif choice == '9':
    #         break
    #     else:
    #         print("Invalid choice. Please try again.")
    #         continue

        # area = shape.calculate_area()
        # print(f"The area of the shape is {area}")

# %%
Pogram 1

class Shape:
    def __init__(self, sides, measurements):
        self.sides = sides
        self.measurements = measurements

    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        super().__init__(1, [radius])

    def calculate_area(self):
        return 3.14159 * self.measurements[0] * self.measurements[0]

class Square(Shape):
    def __init__(self, side):
        super().__init__(4, [side] * 4)

    def calculate_area(self):
        return self.measurements[0] * self.measurements[0]

class Rectangle(Shape):
    def __init__(self, length, width):
        super().__init__(4, [length, width] * 2)

    def calculate_area(self):
        return self.measurements[0] * self.measurements[1]

class Rhombus(Shape):
    def __init__(self, side):
        super().__init__(4, [side] * 4)

    def calculate_area(self):
        return 0.5 * self.measurements[0] * self.measurements[1]

class Parallelogram(Shape):
    def __init__(self, base, height):
        super().__init__(4, [base, height] * 2)

    def calculate_area(self):
        return self.measurements[0] * self.measurements[1]

def menu():
    print("1. Enter the Number of sides")
    choice = int(input("Enter your choice: "))
    if choice == 4:
        shape = Square(float(input("Enter the side: "))).calculate_area()
        shape = Rectangle(float(input("Enter the length: ")), float(input("Enter the width: "))).calculate_area()
        shape = Parallelogram(float(input("Enter the base: ")), float(input("Enter the height: "))).calculate_area()
        shape = Rhombus(float(input("Enter the side: "))).calculate_area()
    elif choice == 0:
        shape = Circle(float(input("Enter the radius: "))).calculate_area()
    else:
        print("Invalid choice. Please enter a valid choice.")
        return

    # print("The area of the shape is: ", shape.calculate_area())
    

menu()
