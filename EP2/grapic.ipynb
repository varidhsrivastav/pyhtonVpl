# %%
# Imagine a 2D Graphics application with various shapes such as circle, square, rhombus, rectangle, paralelogram.Calculate the area for each shape depending on the number of sides and measurement of each side taken from the user. The programs should be a menu driven program that decides which shape is being calculated depending on the number of sides and measurements of each side. ?

# method resolution operator or mro
import math
# base class 1
class shape:
    def __init__(self, sides):
        self.sides=sides
    def __str__(self):
        return f"shapes with {self.sides} sides"
# base class 2 child class1
class circle(shape):
    def __init__(self,sides, radius):
        super().__init__(sides)
        self._radius = radius
    def area(self):
        return f"the area of circle is {math.pi * (self._radius ** 2)}"
class paralelogram(shape):
    def __init__(self, sides, base,height):
        assert len(sides)==3,"a parallelogram must have exactly three side lengths"
        super().__init__(len(sides))
        self.base=base
        self.height=height
    def area(self):
        return f"The area of a parallelogram is {self.base*self.height}"
class rectangle(shape):
    def __init__(self, sides, legth, bre):
        assert len(sides)==4,"A rectangle must have four side length"
        super().__init__(len(sides))
        self.leght=legth
        self.bre=bre
    def area(self):
        return f"the area of the rectangle is {self.leght*self.bre}"
class Rohmbus(shape):
    def area(self, sides,dia1, dia2):
        super().__init__(sides)
        self.diameter1 = dia1
        self.diameter2 = dia2
    def area(self):
        return (self.diameter1 * self.diameter2)/2
class square(shape):
    def __init__(self, sides, s_lenght):
        super().__init__(sides)
        self.s_lenght= s_lenght
    def area(self):
        return self.s_lenght**2
# tri=Triangle(3,5)
# tri.area()
# sqa=square(4,4)
# Triangle.mro()
# square.mro()
# sqa.area()

# %%
import math
class Shape:
    def __init__(self, sides):
        self.sides = sides
    def calculate_area(self):
        pass
class paralelogram(Shape):
    def __init__(self, sides, leght):
        super().__init__(sides)
        self.leght=leght
    def calculate_area(self):
        return f"The area of a parallelogram is {self.sides*self.leght}"
class Circle(Shape):
    def __init__(self, radius):
        super().__init__(radius)
        self.radius = radius
    def calculate_area(self):
        return f"the area od the curcle is {math.pi * self.radius * self.radius}"

class Square(Shape):
    def __init__(self, side):
        super().__init__(side)
        self.side = side
    def calculate_area(self):
        return f"The area of the square is {self.side * self.side}"
class rectangle(Shape):
    def __init__(self, side, bredth):
        super().__init__(side)
        self.side = side
        self.bredth=bredth
    def calculate_area(self):
        return f"The area of the rectangle{self.side * self.bredth}"
class Rohmbus(Shape):
    def __init__(self,dia1, dia2):
        # super().__init__(sides)
        self.dia1 = dia1
        self.dia2 = dia2
    def calculate_area(self):
        return f"The area f the Rohmbus {(self.dia1 * self.dia2)/2}"

    choice1=input("Enter the Number of sides")
    if choice1 == '4':
            print("You have selected 4 sides")
            print("1.square")
            print("2.parallelogram")
            print("3.rectangle")
            print("4.rohmbus")
            shape_type = int(input("Enter your number"))
            sides=int(input('Enter the leght of sides'))
            if shape_type==1:
                print(Square(sides).calculate_area())
            elif shape_type==2:
                base=int(input('Enter the base of the parralelogra'))
                print(paralelogram(sides,base).calculate_area())
            elif shape_type==3:
                 breadth=int(input('Enter the breadth of the rectangle'))
                 print(rectangle(sides, breadth).calculate_area())
            elif shape_type==4:
                dia1=int(input('Enter the diagonal 1'))
                dia2=int(input('Enter the diagonal 2'))
                print(Rohmbus(dia1, dia2).calculate_area())
            else:
                 print("You have selected invalid option")
        
    elif choice1 == '0':
            diameter=int(input('Enter the diameter'))
            print(Circle(diameter).calculate_area())
    else:
            print("Invalid input! Please enter again.")

    # while True:
    #     print("1. Enter")
    #     print("2. Square")
    #     # Add other shape options here...
    #     print("9. Quit")
    #     choice = input("Enter your choice: ")
    #     if choice == '1':
    #         radius = float(input("Enter the radius: "))
    #         shape = Circle(radius)
    #     elif choice == '2':
    #         side = float(input("Enter the side: "))
    #         shape = Square(side)
    #     elif choice =='3':
    #         num_sides = int(input("How many sides does this shape have? "))
    #         side_length = float(input("What is the length of each side? "))
    #         shape = paralelogram([num_sides],side_length)
    #     elif choice == '4':
    #         d1 = float(input("Enter diameter 1: "))
    #         d2 = float(input("Enter diameter 2: "))
    #         # shape = Rohmbus(d1,d2)
    #     # Add other shape options here...

    #     elif choice == '9':
    #         break
    #     else:
    #         print("Invalid choice. Please try again.")
    #         continue

        # area = shape.calculate_area()
        # print(f"The area of the shape is {area}")
# Out:
# the area od the curcle is 28.274333882308138
